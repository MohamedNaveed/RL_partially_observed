# %%
import gymnasium as gym
import numpy as np
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import time
from distutils.util import strtobool
import os

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter

# %%
ENV_NAME = 'InvertedPendulum-v4'
#env = gym.make(ENV_NAME,render_mode = "human")
def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = gym.make(env_id, render_mode = "human")
        env = gym.wrappers.RecordEpisodeStatistics(env)
        env.action_space.seed(seed)
        return env

    return thunk

# %%
# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.single_observation_space.shape).prod() + np.prod(env.single_action_space.shape), 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 1)

    def forward(self, x, a):
        x = torch.cat([x, a], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class Actor(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.single_observation_space.shape).prod(), 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc_mu = nn.Linear(256, np.prod(env.single_action_space.shape))
        # action rescaling
        self.register_buffer(
            "action_scale", torch.tensor((env.action_space.high - env.action_space.low) / 2.0, dtype=torch.float32)
        )
        self.register_buffer(
            "action_bias", torch.tensor((env.action_space.high + env.action_space.low) / 2.0, dtype=torch.float32)
        )

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.tanh(self.fc_mu(x))
        return x * self.action_scale + self.action_bias

# %%
if __name__ == "__main__":

    given_seed = 42
    buffer_size = int(1e6)
    batch_size = 256
    total_timesteps = 2000
    learning_starts = 25e3
    exploration_noise = 0.1
    policy_frequency = 2
    tau = 0.005
    gamma = 0.99
    learning_rate = 3e-4

    exp_name = 'carpole_test'
    run_name = 'test'
    random.seed(given_seed)
    np.random.seed(given_seed)
    torch.manual_seed(given_seed)
    torch.backends.cudnn.deterministic = True
    writer = SummaryWriter(f"runs/{run_name}")
    
    # if GPU is to be used
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    print(f"Using {device}");

    envs = gym.vector.SyncVectorEnv([make_env(ENV_NAME, given_seed, 0, False, run_name)])
    assert isinstance(envs.single_action_space, gym.spaces.Box), "only continuous action space is supported"

    actor = Actor(envs).to(device)
    qf1 = QNetwork(envs).to(device)
    checkpoint = torch.load("/home/naveed/Documents/RL/naveed_codes/runs/test/carpole_test.cleanrl_model")
    actor.load_state_dict(checkpoint[0])
    qf1.load_state_dict(checkpoint[1])
# Out:
# Using cuda

# %%
    actor.eval()
    qf1.eval()
# Out:
# QNetwork(
#   (fc1): Linear(in_features=5, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
    obs, _ = envs.reset(seed=given_seed)

    for global_step in range(total_timesteps):
        with torch.no_grad():
            actions = actor(torch.Tensor(obs).to(device))
            cost_to_go = -qf1(torch.Tensor(obs).to(device), actions)
            actions = actions.cpu().numpy().clip(envs.single_action_space.low, envs.single_action_space.high)
        next_obs, rewards, terminations, truncations, infos = envs.step(actions)
        
        if terminations:
            obs, _ = envs.reset(seed=given_seed)
        #envs.render()
        
        print("observation:", next_obs, " action:", actions, ' CTG=', cost_to_go)
        
        obs = next_obs

    envs.close()
# Out:
# observation: [[0.04957449 3.17068378 2.0852719  0.36467081]]  action: [[7.923197]]  CTG= tensor([[377.7521]], device='cuda:0')
# observation: [[ 0.18197324  3.17234815  4.54865202 -0.1265781 ]]  action: [[9.757704]]  CTG= tensor([[221.7832]], device='cuda:0')
# observation: [[ 0.29860909  3.01704166  1.30360746 -7.48394338]]  action: [[-9.789768]]  CTG= tensor([[12.5328]], device='cuda:0')
# observation: [[  0.29574431   2.60861964  -1.34632877 -12.47255689]]  action: [[-9.010969]]  CTG= tensor([[-200.2743]], device='cuda:0')
# observation: [[  0.23292221   2.12059411  -1.76216392 -11.77216632]]  action: [[-3.3520422]]  CTG= tensor([[-471.6268]], device='cuda:0')
# observation: [[ 0.17084653  1.68834417 -1.37002498 -9.92177123]]  action: [[-0.37427765]]  CTG= tensor([[-582.3936]], device='cuda:0')
# observation: [[ 0.15393051  1.32107615  0.50258285 -8.72301917]]  action: [[5.9974074]]  CTG= tensor([[-711.4035]], device='cuda:0')
# observation: [[ 0.18735346  0.98892711  1.15494558 -7.97755875]]  action: [[1.6947601]]  CTG= tensor([[-791.1482]], device='cuda:0')
# observation: [[ 0.22139727  0.71128205  0.51735414 -5.85707395]]  action: [[-2.4821935]]  CTG= tensor([[-791.2315]], device='cuda:0')
# observation: [[ 0.22840492  0.52022463 -0.18151589 -3.68460426]]  action: [[-2.2393432]]  CTG= tensor([[-849.0952]], device='cuda:0')
# observation: [[ 0.21741236  0.39326305 -0.36973178 -2.68388022]]  action: [[-0.461836]]  CTG= tensor([[-914.6212]], device='cuda:0')
# observation: [[ 0.20131446  0.29839298 -0.43453019 -2.08020072]]  action: [[-0.07052153]]  CTG= tensor([[-891.8439]], device='cuda:0')
# observation: [[ 0.18517923  0.21983885 -0.37105895 -1.86457743]]  action: [[0.30508953]]  CTG= tensor([[-885.0173]], device='cuda:0')
# observation: [[ 0.16978126  0.15234076 -0.39758604 -1.52679564]]  action: [[0.01021446]]  CTG= tensor([[-876.1825]], device='cuda:0')
# observation: [[ 0.1517418   0.1004442  -0.50306264 -1.0833704 ]]  action: [[-0.2507579]]  CTG= tensor([[-860.0107]], device='cuda:0')
# observation: [[ 0.12603205  0.0728767  -0.78089761 -0.31057871]]  action: [[-0.79330766]]  CTG= tensor([[-851.0235]], device='cuda:0')
# observation: [[ 0.09034556  0.07236214 -1.00252957  0.27656468]]  action: [[-0.6468349]]  CTG= tensor([[-860.9360]], device='cuda:0')
# observation: [[ 0.05171368  0.08110943 -0.92942653  0.16417673]]  action: [[0.2312152]]  CTG= tensor([[-880.3401]], device='cuda:0')
# observation: [[ 0.01658034  0.0843099  -0.82757847 -0.00114253]]  action: [[0.32362556]]  CTG= tensor([[-884.0156]], device='cuda:0')
# observation: [[-0.01469536  0.08161642 -0.73637315 -0.1321979 ]]  action: [[0.29622892]]  CTG= tensor([[-880.9014]], device='cuda:0')
# observation: [[-0.0437618   0.07707236 -0.71682652 -0.0963637 ]]  action: [[0.08185819]]  CTG= tensor([[-873.9071]], device='cuda:0')
# observation: [[-0.0719369   0.07359185 -0.69185223 -0.07856124]]  action: [[0.09634481]]  CTG= tensor([[-873.6621]], device='cuda:0')
# observation: [[-0.09897393  0.07042233 -0.6599584  -0.08047999]]  action: [[0.11602689]]  CTG= tensor([[-873.5276]], device='cuda:0')
# observation: [[-0.12479014  0.06724685 -0.63080495 -0.07890996]]  action: [[0.10702956]]  CTG= tensor([[-873.2152]], device='cuda:0')
# observation: [[-0.14952165  0.06426257 -0.60571623 -0.07097296]]  action: [[0.09395174]]  CTG= tensor([[-872.6521]], device='cuda:0')
# observation: [[-0.17305499  0.0610852  -0.57093136 -0.08825218]]  action: [[0.12232956]]  CTG= tensor([[-871.7886]], device='cuda:0')
# observation: [[-0.19505364  0.05684549 -0.52898856 -0.12404543]]  action: [[0.1434719]]  CTG= tensor([[-870.5445]], device='cuda:0')
# observation: [[-0.2154653   0.05134123 -0.49154413 -0.15184478]]  action: [[0.1294428]]  CTG= tensor([[-868.9379]], device='cuda:0')
# observation: [[-0.2348287   0.04568914 -0.47649987 -0.13212992]]  action: [[0.06081623]]  CTG= tensor([[-866.1205]], device='cuda:0')
# observation: [[-0.25375808  0.04109077 -0.46984139 -0.09913819]]  action: [[0.03344981]]  CTG= tensor([[-864.8416]], device='cuda:0')
# observation: [[-0.27234863  0.03752896 -0.45959784 -0.07990699]]  action: [[0.04224951]]  CTG= tensor([[-864.9457]], device='cuda:0')
# observation: [[-0.29056668  0.03473884 -0.45122987 -0.06040595]]  action: [[0.0351837]]  CTG= tensor([[-864.8413]], device='cuda:0')
# observation: [[-0.30850603  0.03278831 -0.44567373 -0.03780603]]  action: [[0.02553194]]  CTG= tensor([[-864.6536]], device='cuda:0')
# observation: [[-0.32614616  0.03150648 -0.43629876 -0.0266784 ]]  action: [[0.03608134]]  CTG= tensor([[-865.0808]], device='cuda:0')
# observation: [[-0.34326326  0.03029381 -0.41955144 -0.03407518]]  action: [[0.057794]]  CTG= tensor([[-865.4178]], device='cuda:0')
# observation: [[-0.35961421  0.02854834 -0.3979993  -0.05325959]]  action: [[0.07215767]]  CTG= tensor([[-864.7429]], device='cuda:0')
# observation: [[-0.37514833  0.02612719 -0.37869001 -0.06805608]]  action: [[0.06532587]]  CTG= tensor([[-863.3939]], device='cuda:0')
# observation: [[-0.39007552  0.02346679 -0.36762094 -0.06551327]]  action: [[0.04008974]]  CTG= tensor([[-861.7156]], device='cuda:0')
# observation: [[-0.4047418   0.02127728 -0.36562478 -0.04467638]]  action: [[0.01190335]]  CTG= tensor([[-860.8213]], device='cuda:0')
# observation: [[-0.41938582  0.01999401 -0.36651856 -0.02007541]]  action: [[0.00213475]]  CTG= tensor([[-859.7574]], device='cuda:0')
# observation: [[-0.4333988   0.01810755 -0.33418237 -0.07385695]]  action: [[0.10148379]]  CTG= tensor([[-858.1318]], device='cuda:0')
# observation: [[-0.4469739   0.01606428 -0.34446889 -0.02932662]]  action: [[-0.02647248]]  CTG= tensor([[-855.6432]], device='cuda:0')
# observation: [[-0.4602213   0.01401436 -0.31793317 -0.07295539]]  action: [[0.08303149]]  CTG= tensor([[-854.0652]], device='cuda:0')
# observation: [[-0.47341273  0.01254713 -0.34150353 -0.00168914]]  action: [[-0.0677565]]  CTG= tensor([[-851.9959]], device='cuda:0')
# observation: [[-0.48579707  0.0097924  -0.27786993 -0.13472128]]  action: [[0.19326472]]  CTG= tensor([[-850.7690]], device='cuda:0')
# observation: [[-0.49831179  0.00797717 -0.34756198  0.04113775]]  action: [[-0.20683266]]  CTG= tensor([[-848.5705]], device='cuda:0')
# observation: [[-0.51099607  0.0069434  -0.28683893 -0.09116984]]  action: [[0.18218966]]  CTG= tensor([[-847.1421]], device='cuda:0')
# observation: [[-0.52305278  0.00488931 -0.31583831 -0.01303426]]  action: [[-0.08590972]]  CTG= tensor([[-844.1973]], device='cuda:0')
# observation: [[-0.53522408  0.00343199 -0.29277198 -0.05946623]]  action: [[0.06880824]]  CTG= tensor([[-842.9943]], device='cuda:0')
# observation: [[-0.54704813  0.00146571 -0.29836349 -0.0395157 ]]  action: [[-0.01710086]]  CTG= tensor([[-840.5449]], device='cuda:0')
# observation: [[-5.59162095e-01  3.95181769e-04 -3.07276330e-01 -1.45717275e-02]]  action: [[-0.02815601]]  CTG= tensor([[-839.2004]], device='cuda:0')
# observation: [[-5.71651446e-01  3.22047335e-04 -3.17151376e-01  1.05488774e-02]]  action: [[-0.03190961]]  CTG= tensor([[-838.3862]], device='cuda:0')
# observation: [[-0.58444639  0.00102117 -0.32258819  0.02435326]]  action: [[-0.01905768]]  CTG= tensor([[-837.8873]], device='cuda:0')
# observation: [[-0.59732516  0.00196286 -0.32137096  0.02293947]]  action: [[0.00096203]]  CTG= tensor([[-837.3464]], device='cuda:0')
# observation: [[-0.61010029  0.00273955 -0.31741181  0.0161465 ]]  action: [[0.00958175]]  CTG= tensor([[-836.5665]], device='cuda:0')
# observation: [[-0.62273179  0.00329931 -0.31418116  0.01201318]]  action: [[0.00779749]]  CTG= tensor([[-835.8105]], device='cuda:0')
# observation: [[-0.63530076  0.00386202 -0.31427292  0.01617807]]  action: [[-0.00192999]]  CTG= tensor([[-835.3136]], device='cuda:0')
# observation: [[-0.64793786  0.0047463  -0.31758187  0.02804775]]  action: [[-0.01150607]]  CTG= tensor([[-835.0359]], device='cuda:0')
# observation: [[-0.66071918  0.00613712 -0.32149123  0.04158218]]  action: [[-0.01324086]]  CTG= tensor([[-834.9807]], device='cuda:0')
# observation: [[-0.67358332  0.00791128 -0.32174206  0.04740084]]  action: [[-0.00199764]]  CTG= tensor([[-834.9999]], device='cuda:0')
# observation: [[-0.68635907  0.00971732 -0.31708824  0.04332168]]  action: [[0.01329304]]  CTG= tensor([[-834.9744]], device='cuda:0')
# observation: [[-0.69888727  0.01125516 -0.30936832  0.03401225]]  action: [[0.02326041]]  CTG= tensor([[-834.8560]], device='cuda:0')
# observation: [[-0.71111605  0.01247931 -0.30210684  0.02753578]]  action: [[0.02262622]]  CTG= tensor([[-834.4867]], device='cuda:0')
# observation: [[-0.72307038  0.01350993 -0.29563724  0.02425328]]  action: [[0.02083034]]  CTG= tensor([[-833.9431]], device='cuda:0')
# observation: [[-0.73480857  0.01452967 -0.29129123  0.02690711]]  action: [[0.01489461]]  CTG= tensor([[-833.5170]], device='cuda:0')
# observation: [[-0.74645163  0.01585321 -0.29087137  0.03936607]]  action: [[0.00340373]]  CTG= tensor([[-833.4024]], device='cuda:0')
# observation: [[-0.7581183   0.01778014 -0.29247521  0.05712237]]  action: [[-0.00244617]]  CTG= tensor([[-833.6470]], device='cuda:0')
# observation: [[-0.76980048  0.02032241 -0.29166572  0.07032037]]  action: [[0.00517965]]  CTG= tensor([[-834.1171]], device='cuda:0')
# observation: [[-0.78134311  0.02317824 -0.28552119  0.07301167]]  action: [[0.0219208]]  CTG= tensor([[-833.5231]], device='cuda:0')
# observation: [[-0.79252623  0.02592824 -0.27370503  0.06515761]]  action: [[0.04000689]]  CTG= tensor([[-832.4504]], device='cuda:0')
# observation: [[-0.80316161  0.02824829 -0.25813523  0.05151152]]  action: [[0.05250175]]  CTG= tensor([[-831.3156]], device='cuda:0')
# observation: [[-0.81322729  0.03020061 -0.24520058  0.04657693]]  action: [[0.04571729]]  CTG= tensor([[-830.1246]], device='cuda:0')
# observation: [[-0.82282387  0.03210726 -0.23466776  0.04911504]]  action: [[0.03934439]]  CTG= tensor([[-829.1260]], device='cuda:0')
# observation: [[-0.8319814   0.03410656 -0.22325072  0.05123454]]  action: [[0.04272068]]  CTG= tensor([[-828.3342]], device='cuda:0')
# observation: [[-0.8406144   0.03606823 -0.20845103  0.04731217]]  action: [[0.05367893]]  CTG= tensor([[-827.6494]], device='cuda:0')
# observation: [[-0.84860532  0.03779681 -0.19114787  0.03958772]]  action: [[0.06210487]]  CTG= tensor([[-826.9756]], device='cuda:0')
# observation: [[-0.85588286  0.03920634 -0.17277766  0.03130552]]  action: [[0.06620622]]  CTG= tensor([[-826.3425]], device='cuda:0')
# observation: [[-0.8624257   0.04031857 -0.15440503  0.02464128]]  action: [[0.0670082]]  CTG= tensor([[-825.7961]], device='cuda:0')
# observation: [[-0.86824085  0.0412076  -0.13638571  0.02007304]]  action: [[0.06661034]]  CTG= tensor([[-825.4434]], device='cuda:0')
# observation: [[-0.87334081  0.04194742 -0.11864017  0.01712792]]  action: [[0.06633944]]  CTG= tensor([[-825.2607]], device='cuda:0')
# observation: [[-0.87773072  0.04258523 -0.10088042  0.01494245]]  action: [[0.0668577]]  CTG= tensor([[-825.1896]], device='cuda:0')
# observation: [[-0.88142183  0.04317608 -0.08369616  0.01474309]]  action: [[0.06555058]]  CTG= tensor([[-825.4347]], device='cuda:0')
# observation: [[-0.88441841  0.04375337 -0.06615462  0.01426597]]  action: [[0.06700343]]  CTG= tensor([[-825.7047]], device='cuda:0')
# observation: [[-0.88669375  0.04427735 -0.04763579  0.0120907 ]]  action: [[0.07032992]]  CTG= tensor([[-825.7682]], device='cuda:0')
# observation: [[-0.8882055   0.04467325 -0.02797558  0.00786605]]  action: [[0.0741705]]  CTG= tensor([[-825.9844]], device='cuda:0')
# observation: [[-0.88891246  0.04486913 -0.00739553  0.00207173]]  action: [[0.0773438]]  CTG= tensor([[-826.3435]], device='cuda:0')
# observation: [[-0.88878651  0.04482008  0.01367371 -0.00441897]]  action: [[0.07918467]]  CTG= tensor([[-826.8308]], device='cuda:0')
# observation: [[-0.88781696  0.04451497  0.03478979 -0.01078384]]  action: [[0.07962424]]  CTG= tensor([[-827.4330]], device='cuda:0')
# observation: [[-0.88599249  0.04393228  0.05642326 -0.01833673]]  action: [[0.08139477]]  CTG= tensor([[-828.1831]], device='cuda:0')
# observation: [[-0.88330127  0.04304109  0.07813235 -0.02626519]]  action: [[0.08176282]]  CTG= tensor([[-829.0542]], device='cuda:0')
# observation: [[-0.87973597  0.0418112   0.10013211 -0.03532375]]  action: [[0.08268161]]  CTG= tensor([[-830.0655]], device='cuda:0')
# observation: [[-0.87530118  0.04022977  0.12161491 -0.04391924]]  action: [[0.08107052]]  CTG= tensor([[-831.1729]], device='cuda:0')
# observation: [[-0.87003399  0.03834638  0.14176129 -0.05051064]]  action: [[0.07685625]]  CTG= tensor([[-832.3457]], device='cuda:0')
# observation: [[-0.86401847  0.0363044   0.15904282 -0.05195323]]  action: [[0.06788497]]  CTG= tensor([[-833.5124]], device='cuda:0')
# observation: [[-0.85736534  0.03429294  0.17364803 -0.04904077]]  action: [[0.05931808]]  CTG= tensor([[-834.6984]], device='cuda:0')
# observation: [[-0.85015853  0.03242907  0.18672717 -0.04456688]]  action: [[0.05413431]]  CTG= tensor([[-835.9520]], device='cuda:0')
# observation: [[-0.84243288  0.03071594  0.19958557 -0.04145629]]  action: [[0.05289663]]  CTG= tensor([[-837.3166]], device='cuda:0')
# observation: [[-0.83406641  0.0288011   0.21874733 -0.05446676]]  action: [[0.0714025]]  CTG= tensor([[-839.1116]], device='cuda:0')
# observation: [[-0.82488025  0.02622104  0.24057198 -0.07474906]]  action: [[0.07918288]]  CTG= tensor([[-841.1102]], device='cuda:0')
# observation: [[-0.81484576  0.02285975  0.26118134 -0.09370314]]  action: [[0.07518674]]  CTG= tensor([[-843.2653]], device='cuda:0')
# observation: [[-0.80406935  0.01888835  0.27769158 -0.10547796]]  action: [[0.06219815]]  CTG= tensor([[-844.7443]], device='cuda:0')
# observation: [[-0.79260217  0.01431542  0.29572171 -0.12380946]]  action: [[0.06578869]]  CTG= tensor([[-846.4108]], device='cuda:0')
# observation: [[-0.78040785  0.0089306   0.31405915 -0.14617895]]  action: [[0.06564028]]  CTG= tensor([[-847.4197]], device='cuda:0')
# observation: [[-0.76745247  0.00251172  0.33378443 -0.17562139]]  action: [[0.06854329]]  CTG= tensor([[-846.0515]], device='cuda:0')
# observation: [[-0.75373602 -0.00510774  0.35213481 -0.20642908]]  action: [[0.0628976]]  CTG= tensor([[-844.0441]], device='cuda:0')
# observation: [[-0.74021611 -0.01191796  0.32409978 -0.13641976]]  action: [[-0.07883626]]  CTG= tensor([[-841.6211]], device='cuda:0')
# observation: [[-0.72741642 -0.01704681  0.31600836 -0.12125934]]  action: [[-0.02242623]]  CTG= tensor([[-840.0389]], device='cuda:0')
# observation: [[-0.71512191 -0.02125795  0.29884875 -0.09057332]]  action: [[-0.0518282]]  CTG= tensor([[-839.3384]], device='cuda:0')
# observation: [[-0.70351533 -0.02434467  0.28158358 -0.06474833]]  action: [[-0.05424008]]  CTG= tensor([[-839.2822]], device='cuda:0')
# observation: [[-0.69262396 -0.02642298  0.26306812 -0.03994045]]  action: [[-0.05964499]]  CTG= tensor([[-839.6549]], device='cuda:0')
# observation: [[-0.68240593 -0.02772644  0.24788553 -0.02570388]]  action: [[-0.05088496]]  CTG= tensor([[-839.7590]], device='cuda:0')
# observation: [[-0.67278178 -0.0285291   0.23336027 -0.01475602]]  action: [[-0.04972566]]  CTG= tensor([[-840.0667]], device='cuda:0')
# observation: [[-0.6637222  -0.02895714  0.21964499 -0.00685528]]  action: [[-0.04787673]]  CTG= tensor([[-840.4880]], device='cuda:0')
# observation: [[-0.65519461 -0.02912305  0.20675165 -0.00156154]]  action: [[-0.04580757]]  CTG= tensor([[-840.8434]], device='cuda:0')
# observation: [[-0.6471715  -0.02911143  0.19441545  0.00207961]]  action: [[-0.04439793]]  CTG= tensor([[-841.1526]], device='cuda:0')
# observation: [[-0.63963572 -0.02897164  0.18238091  0.00488414]]  action: [[-0.04366628]]  CTG= tensor([[-841.4229]], device='cuda:0')
# observation: [[-0.63253899 -0.02881766  0.1724558   0.0028597 ]]  action: [[-0.03742392]]  CTG= tensor([[-841.6047]], device='cuda:0')
# observation: [[-0.62584598 -0.02872435  0.1621971   0.00182499]]  action: [[-0.03844434]]  CTG= tensor([[-841.8998]], device='cuda:0')
# observation: [[-0.6195662  -0.02866307  0.15179581  0.00124532]]  action: [[-0.03892863]]  CTG= tensor([[-842.1607]], device='cuda:0')
# observation: [[-0.6137083  -0.02860983  0.14110424  0.00141093]]  action: [[-0.03987783]]  CTG= tensor([[-842.3789]], device='cuda:0')
# observation: [[-0.60828864 -0.02852476  0.12988539  0.00282595]]  action: [[-0.04155927]]  CTG= tensor([[-842.5651]], device='cuda:0')
# observation: [[-0.60333363 -0.02834622  0.11787257  0.0060769 ]]  action: [[-0.04405938]]  CTG= tensor([[-842.7378]], device='cuda:0')
# observation: [[-0.59887207 -0.02800775  0.1052124   0.01083338]]  action: [[-0.04612317]]  CTG= tensor([[-842.7521]], device='cuda:0')
# observation: [[-0.594875   -0.02757432  0.09463841  0.01090947]]  action: [[-0.03992134]]  CTG= tensor([[-842.6604]], device='cuda:0')
# observation: [[-0.59131778 -0.02709109  0.08322283  0.01330148]]  action: [[-0.04241906]]  CTG= tensor([[-842.5145]], device='cuda:0')
# observation: [[-0.58823132 -0.02647312  0.0711007   0.01764573]]  action: [[-0.0445383]]  CTG= tensor([[-842.3444]], device='cuda:0')
# observation: [[-0.58560851 -0.02572348  0.06003447  0.01994023]]  action: [[-0.04133635]]  CTG= tensor([[-842.2876]], device='cuda:0')
# observation: [[-0.5834197  -0.02489068  0.04939801  0.02182624]]  action: [[-0.03993416]]  CTG= tensor([[-842.2181]], device='cuda:0')
# observation: [[-0.58164039 -0.02400607  0.03955706  0.02255764]]  action: [[-0.03739024]]  CTG= tensor([[-842.1689]], device='cuda:0')
# observation: [[-0.58024759 -0.02309333  0.0300715   0.02323927]]  action: [[-0.03612931]]  CTG= tensor([[-842.0964]], device='cuda:0')
# observation: [[-0.57921089 -0.0221913   0.02174896  0.02204714]]  action: [[-0.03241953]]  CTG= tensor([[-842.0582]], device='cuda:0')
# observation: [[-0.57847211 -0.02140022  0.01517266  0.01771458]]  action: [[-0.02691326]]  CTG= tensor([[-842.0885]], device='cuda:0')
# observation: [[-0.5779967  -0.0207631   0.00858491  0.01430536]]  action: [[-0.02667603]]  CTG= tensor([[-842.0663]], device='cuda:0')
# observation: [[-0.57778493 -0.02024713  0.00199362  0.01162331]]  action: [[-0.02648202]]  CTG= tensor([[-841.9705]], device='cuda:0')
# observation: [[-0.57785843 -0.01977655 -0.00567263  0.01198463]]  action: [[-0.02957103]]  CTG= tensor([[-841.7420]], device='cuda:0')
# observation: [[-0.57822337 -0.01931843 -0.0125811   0.01101673]]  action: [[-0.02720949]]  CTG= tensor([[-841.5600]], device='cuda:0')
# observation: [[-0.57887632 -0.01886285 -0.02006963  0.01183228]]  action: [[-0.02885666]]  CTG= tensor([[-841.2847]], device='cuda:0')
# observation: [[-0.57987131 -0.01826902 -0.02967827  0.01788346]]  action: [[-0.03518219]]  CTG= tensor([[-840.8665]], device='cuda:0')
# observation: [[-0.58121572 -0.017509   -0.0375493   0.02022676]]  action: [[-0.0299358]]  CTG= tensor([[-840.6542]], device='cuda:0')
# observation: [[-0.58280959 -0.01679477 -0.04216147  0.01568247]]  action: [[-0.01996992]]  CTG= tensor([[-840.7350]], device='cuda:0')
# observation: [[-0.58459344 -0.0162322  -0.04704311  0.01259293]]  action: [[-0.02051352]]  CTG= tensor([[-840.5557]], device='cuda:0')
# observation: [[-0.58659119 -0.01573693 -0.05285132  0.01226599]]  action: [[-0.02311556]]  CTG= tensor([[-840.3181]], device='cuda:0')
# observation: [[-0.58882629 -0.01523385 -0.05890909  0.01297085]]  action: [[-0.02375303]]  CTG= tensor([[-840.0988]], device='cuda:0')
# observation: [[-0.59129769 -0.01470802 -0.06466756  0.0134121 ]]  action: [[-0.02275227]]  CTG= tensor([[-839.8857]], device='cuda:0')
# observation: [[-0.59399153 -0.01417371 -0.07003146  0.01340299]]  action: [[-0.02144931]]  CTG= tensor([[-839.6597]], device='cuda:0')
# observation: [[-0.59689425 -0.01364314 -0.0751126   0.01322677]]  action: [[-0.02046941]]  CTG= tensor([[-839.4150]], device='cuda:0')
# observation: [[-0.59999627 -0.01311897 -0.07999583  0.01308173]]  action: [[-0.01974104]]  CTG= tensor([[-839.1552]], device='cuda:0')
# observation: [[-0.60328995 -0.01259942 -0.08469573  0.01299425]]  action: [[-0.01905738]]  CTG= tensor([[-838.8906]], device='cuda:0')
# observation: [[-0.60676763 -0.01208309 -0.08919589  0.01292003]]  action: [[-0.01832484]]  CTG= tensor([[-838.6687]], device='cuda:0')
# observation: [[-0.61044353 -0.01151825 -0.09460353  0.01539422]]  action: [[-0.02092956]]  CTG= tensor([[-838.5001]], device='cuda:0')
# observation: [[-0.61433806 -0.01084126 -0.1001288   0.01854061]]  action: [[-0.02118675]]  CTG= tensor([[-838.3667]], device='cuda:0')
# observation: [[-0.61843687 -0.01006785 -0.1048222   0.02025434]]  action: [[-0.01855551]]  CTG= tensor([[-838.2483]], device='cuda:0')
# observation: [[-0.62269844 -0.00927127 -0.10827049  0.01973587]]  action: [[-0.01461445]]  CTG= tensor([[-838.1319]], device='cuda:0')
# observation: [[-0.62707841 -0.00852561 -0.11074338  0.0177199 ]]  action: [[-0.01143037]]  CTG= tensor([[-838.0172]], device='cuda:0')
# observation: [[-0.63155058 -0.00786057 -0.11287958  0.01568905]]  action: [[-0.01015513]]  CTG= tensor([[-837.8787]], device='cuda:0')
# observation: [[-0.63611234 -0.00725315 -0.11521998  0.0148116 ]]  action: [[-0.01053422]]  CTG= tensor([[-837.7336]], device='cuda:0')
# observation: [[-0.64077439 -0.00665354 -0.11789206  0.0152787 ]]  action: [[-0.01133769]]  CTG= tensor([[-837.5992]], device='cuda:0')
# observation: [[-0.64554445 -0.00602223 -0.12062024  0.01639397]]  action: [[-0.01133799]]  CTG= tensor([[-837.4824]], device='cuda:0')
# observation: [[-0.65041645 -0.00535256 -0.12299032  0.0172085 ]]  action: [[-0.01008986]]  CTG= tensor([[-837.3775]], device='cuda:0')
# observation: [[-0.65538952 -0.00462451 -0.12567294  0.01930737]]  action: [[-0.01084207]]  CTG= tensor([[-837.3262]], device='cuda:0')
# observation: [[-0.66047813 -0.00378234 -0.1287676   0.02291636]]  action: [[-0.01189827]]  CTG= tensor([[-837.3401]], device='cuda:0')
# observation: [[-0.66568304 -0.00280138 -0.13149109  0.02627772]]  action: [[-0.01058309]]  CTG= tensor([[-837.3047]], device='cuda:0')
# observation: [[-0.67098616 -0.00169629 -0.13368131  0.02915527]]  action: [[-0.00872462]]  CTG= tensor([[-837.3252]], device='cuda:0')
# observation: [[-6.76360886e-01 -4.95873366e-04 -1.35074712e-01  3.10770745e-02]]  action: [[-0.00601648]]  CTG= tensor([[-837.3850]], device='cuda:0')
# observation: [[-0.68176816  0.00074774 -0.1353126   0.0313473 ]]  action: [[-0.00217139]]  CTG= tensor([[-837.4547]], device='cuda:0')
# observation: [[-0.68716183  0.00197104 -0.13439685  0.03007975]]  action: [[0.0017208]]  CTG= tensor([[-837.5132]], device='cuda:0')
# observation: [[-0.69250164  0.00312724 -0.13261938  0.0279912 ]]  action: [[0.00476242]]  CTG= tensor([[-837.5531]], device='cuda:0')
# observation: [[-0.69776107  0.00420152 -0.13037719  0.02596671]]  action: [[0.00660629]]  CTG= tensor([[-837.5809]], device='cuda:0')
# observation: [[-0.70292781  0.00520933 -0.12798248  0.02464568]]  action: [[0.00748486]]  CTG= tensor([[-837.6121]], device='cuda:0')
# observation: [[-0.70799793  0.00618194 -0.12554407  0.02418771]]  action: [[0.00800312]]  CTG= tensor([[-837.6615]], device='cuda:0')
# observation: [[-0.71296368  0.00713853 -0.12276388  0.02384079]]  action: [[0.00939459]]  CTG= tensor([[-837.7254]], device='cuda:0')
# observation: [[-0.71780933  0.00807839 -0.11953913  0.02335012]]  action: [[0.01109213]]  CTG= tensor([[-837.8035]], device='cuda:0')
# observation: [[-0.72251589  0.00899283 -0.11580988  0.02256939]]  action: [[0.01297147]]  CTG= tensor([[-837.8920]], device='cuda:0')
# observation: [[-0.72706312  0.00986991 -0.11157246  0.0214797 ]]  action: [[0.01486302]]  CTG= tensor([[-837.9861]], device='cuda:0')
# observation: [[-0.73143169  0.01069921 -0.10687631  0.02017407]]  action: [[0.01660288]]  CTG= tensor([[-838.0850]], device='cuda:0')
# observation: [[-0.73560471  0.01147481 -0.10179428  0.01878574]]  action: [[0.01811505]]  CTG= tensor([[-838.1881]], device='cuda:0')
# observation: [[-0.73956817  0.0121958  -0.09639738  0.01743278]]  action: [[0.01940012]]  CTG= tensor([[-838.2970]], device='cuda:0')
# observation: [[-0.74331032  0.01286453 -0.09072788  0.01616145]]  action: [[0.02054185]]  CTG= tensor([[-838.4140]], device='cuda:0')
# observation: [[-0.74682048  0.01348376 -0.0847973   0.01494764]]  action: [[0.02163261]]  CTG= tensor([[-838.5403]], device='cuda:0')
# observation: [[-0.75008936  0.01405748 -0.0786626   0.01387498]]  action: [[0.02253652]]  CTG= tensor([[-838.6794]], device='cuda:0')
# observation: [[-0.75313252  0.01464516 -0.0735072   0.01560959]]  action: [[0.01985699]]  CTG= tensor([[-838.9016]], device='cuda:0')
# observation: [[-0.75597307  0.01531951 -0.0685328   0.01821381]]  action: [[0.01953393]]  CTG= tensor([[-839.2570]], device='cuda:0')
# observation: [[-0.75860113  0.01607649 -0.06288617  0.01977234]]  action: [[0.02179682]]  CTG= tensor([[-839.6778]], device='cuda:0')
# observation: [[-0.76097116  0.01683371 -0.05563593  0.0182691 ]]  action: [[0.02691924]]  CTG= tensor([[-839.9193]], device='cuda:0')
# observation: [[-0.7630129   0.0174576  -0.04647485  0.01313092]]  action: [[0.03303347]]  CTG= tensor([[-840.0462]], device='cuda:0')
# observation: [[-0.76466965  0.01784952 -0.03638457  0.00664373]]  action: [[0.03622052]]  CTG= tensor([[-840.2029]], device='cuda:0')
# observation: [[-0.7659241   0.01799845 -0.02635362  0.0009226 ]]  action: [[0.03637967]]  CTG= tensor([[-840.3811]], device='cuda:0')
# observation: [[-0.76679146  0.01795954 -0.01702366 -0.00281293]]  action: [[0.03450898]]  CTG= tensor([[-840.5794]], device='cuda:0')
# observation: [[-0.76730316  0.0178147  -0.00856539 -0.00442547]]  action: [[0.03202109]]  CTG= tensor([[-840.8010]], device='cuda:0')
# observation: [[-7.67489704e-01  1.76347368e-02 -7.63005280e-04 -4.59583538e-03]]  action: [[0.0301051]]  CTG= tensor([[-841.0514]], device='cuda:0')
# observation: [[-0.76736924  0.01745662  0.00678569 -0.00433928]]  action: [[0.02936004]]  CTG= tensor([[-841.3348]], device='cuda:0')
# observation: [[-0.76694443  0.01727974  0.01445359 -0.00452727]]  action: [[0.02973049]]  CTG= tensor([[-841.6534]], device='cuda:0')
# observation: [[-0.76620637  0.01707722  0.02244755 -0.00561389]]  action: [[0.03073333]]  CTG= tensor([[-842.0052]], device='cuda:0')
# observation: [[-0.76514205  0.01681362  0.03076646 -0.00758125]]  action: [[0.03174184]]  CTG= tensor([[-842.3877]], device='cuda:0')
# observation: [[-0.76374167  0.01646086  0.03925127 -0.01008206]]  action: [[0.03226755]]  CTG= tensor([[-842.7965]], device='cuda:0')
# observation: [[-0.76200311  0.01600692  0.04767768 -0.01265956]]  action: [[0.03209708]]  CTG= tensor([[-843.2276]], device='cuda:0')
# observation: [[-0.75993271  0.01545625  0.05584541 -0.01494236]]  action: [[0.03128915]]  CTG= tensor([[-843.6786]], device='cuda:0')
# observation: [[-0.75753695  0.01480965  0.06394697 -0.01747143]]  action: [[0.03102152]]  CTG= tensor([[-844.1539]], device='cuda:0')
# observation: [[-0.75482138  0.01406246  0.07183853 -0.01999282]]  action: [[0.03029107]]  CTG= tensor([[-844.6463]], device='cuda:0')
# observation: [[-0.7517988   0.01322333  0.07929991 -0.02209262]]  action: [[0.02886056]]  CTG= tensor([[-845.0352]], device='cuda:0')
# observation: [[-0.74848945  0.01231406  0.08617945 -0.02352378]]  action: [[0.02693056]]  CTG= tensor([[-845.2227]], device='cuda:0')
# observation: [[-0.74491744  0.0113614   0.09243474 -0.02428081]]  action: [[0.02483249]]  CTG= tensor([[-845.3969]], device='cuda:0')
# observation: [[-0.74110652  0.01038801  0.09812665 -0.02457104]]  action: [[0.0228861]]  CTG= tensor([[-845.5626]], device='cuda:0')
# observation: [[-0.7370768   0.00940615  0.10337533 -0.02470855]]  action: [[0.02128184]]  CTG= tensor([[-845.7227]], device='cuda:0')
# observation: [[-0.73284347  0.00841578  0.1083071  -0.02499708]]  action: [[0.02004862]]  CTG= tensor([[-845.8757]], device='cuda:0')
# observation: [[-0.72841767  0.00740728  0.11299898 -0.0256144 ]]  action: [[0.01904399]]  CTG= tensor([[-846.0175]], device='cuda:0')
# observation: [[-0.72380898  0.00636745  0.11745215 -0.02656546]]  action: [[0.01803965]]  CTG= tensor([[-846.1427]], device='cuda:0')
# observation: [[-0.71899817  0.00521627  0.12310129 -0.03115367]]  action: [[0.02135277]]  CTG= tensor([[-846.1670]], device='cuda:0')
# observation: [[-0.71391112  0.00374908  0.13126035 -0.04233648]]  action: [[0.02865969]]  CTG= tensor([[-846.0020]], device='cuda:0')
# observation: [[-0.70847053  0.00175622  0.14078249 -0.05748681]]  action: [[0.03253339]]  CTG= tensor([[-845.6969]], device='cuda:0')
# observation: [[-0.70268001 -0.00079239  0.14877207 -0.07026862]]  action: [[0.02757727]]  CTG= tensor([[-845.2300]], device='cuda:0')
# observation: [[-0.69663524 -0.00373496  0.1535112  -0.07734416]]  action: [[0.01720101]]  CTG= tensor([[-844.2750]], device='cuda:0')
# observation: [[-0.69049232 -0.00679579  0.15369528 -0.07632046]]  action: [[0.00263424]]  CTG= tensor([[-843.1703]], device='cuda:0')
# observation: [[-0.68453537 -0.00942562  0.14423514 -0.05598166]]  action: [[-0.02749083]]  CTG= tensor([[-842.4164]], device='cuda:0')
# observation: [[-0.67914047 -0.01088544  0.12559853 -0.01783893]]  action: [[-0.05646779]]  CTG= tensor([[-842.4772]], device='cuda:0')
# observation: [[-0.67450863 -0.01084292  0.10605218  0.01944525]]  action: [[-0.06050508]]  CTG= tensor([[-843.0416]], device='cuda:0')
# observation: [[-0.67048076 -0.00975583  0.09534662  0.0349036 ]]  action: [[-0.03463353]]  CTG= tensor([[-843.5927]], device='cuda:0')
# observation: [[-0.66661132 -0.00866904  0.09808322  0.01985864]]  action: [[0.00590266]]  CTG= tensor([[-844.1322]], device='cuda:0')
# observation: [[-0.66245928 -0.00854942  0.10946659 -0.01339103]]  action: [[0.032607]]  CTG= tensor([[-844.2809]], device='cuda:0')
# observation: [[-0.65782339 -0.00979074  0.12229857 -0.04843288]]  action: [[0.03766355]]  CTG= tensor([[-844.0911]], device='cuda:0')
# observation: [[-0.65271352 -0.01233098  0.13319834 -0.07866273]]  action: [[0.03211109]]  CTG= tensor([[-843.3875]], device='cuda:0')
# observation: [[-0.64749419 -0.01534255  0.12783783 -0.07260434]]  action: [[-0.01717328]]  CTG= tensor([[-842.0480]], device='cuda:0')
# observation: [[-0.64277275 -0.01751764  0.10833363 -0.03708833]]  action: [[-0.06098519]]  CTG= tensor([[-841.2041]], device='cuda:0')
# observation: [[-0.63880615 -0.018405    0.09006187 -0.00787416]]  action: [[-0.05877358]]  CTG= tensor([[-840.9434]], device='cuda:0')
# observation: [[-0.6357012  -0.01786662  0.06524422  0.03429955]]  action: [[-0.0794618]]  CTG= tensor([[-841.2242]], device='cuda:0')
# observation: [[-0.63339893 -0.01611191  0.04986935  0.05350675]]  action: [[-0.05173671]]  CTG= tensor([[-841.8236]], device='cuda:0')
# observation: [[-0.63144412 -0.01419384  0.04782089  0.04291896]]  action: [[-0.01142858]]  CTG= tensor([[-842.6647]], device='cuda:0')
# observation: [[-0.6293798  -0.01309628  0.05533038  0.01259571]]  action: [[0.01818508]]  CTG= tensor([[-843.2444]], device='cuda:0')
# observation: [[-0.626976   -0.01325221  0.0648147  -0.01997154]]  action: [[0.02507299]]  CTG= tensor([[-843.2386]], device='cuda:0')
# observation: [[-0.62418205 -0.01470646  0.07486234 -0.05257801]]  action: [[0.02733766]]  CTG= tensor([[-842.6732]], device='cuda:0')
# observation: [[-0.62124523 -0.01686098  0.07201789 -0.05554081]]  action: [[-0.0113958]]  CTG= tensor([[-842.4528]], device='cuda:0')
# observation: [[-0.61877507 -0.01835521  0.05157737 -0.0199746 ]]  action: [[-0.06515568]]  CTG= tensor([[-841.6787]], device='cuda:0')
# observation: [[-0.61701952 -0.01872678  0.03624344  0.00101882]]  action: [[-0.05104321]]  CTG= tensor([[-840.9081]], device='cuda:0')
# observation: [[-0.61592902 -0.01816664  0.01831435  0.02673002]]  action: [[-0.05948406]]  CTG= tensor([[-840.3373]], device='cuda:0')
# observation: [[-0.61551358 -0.01669042  0.00246439  0.04707992]]  action: [[-0.05361841]]  CTG= tensor([[-840.4132]], device='cuda:0')
# observation: [[-0.6155276  -0.01486586 -0.00320072  0.04453822]]  action: [[-0.0228986]]  CTG= tensor([[-840.9490]], device='cuda:0')
# observation: [[-6.15589353e-01 -1.35204930e-02  5.72422181e-05  2.32888197e-02]]  action: [[0.00460417]]  CTG= tensor([[-841.6563]], device='cuda:0')
# observation: [[-0.61543661 -0.01317422  0.0075314  -0.00550843]]  action: [[0.01814455]]  CTG= tensor([[-841.6241]], device='cuda:0')
# observation: [[-0.61500684 -0.01389453  0.01393477 -0.03030783]]  action: [[0.01557172]]  CTG= tensor([[-841.2095]], device='cuda:0')
# observation: [[-0.61445453 -0.01528694  0.01369615 -0.03946664]]  action: [[-0.00423281]]  CTG= tensor([[-840.7303]], device='cuda:0')
# observation: [[-0.61420396 -0.01638706 -0.00110777 -0.01609319]]  action: [[-0.04847069]]  CTG= tensor([[-840.3098]], device='cuda:0')
# observation: [[-0.61458736 -0.01649865 -0.01801641  0.0101163 ]]  action: [[-0.0557129]]  CTG= tensor([[-839.4318]], device='cuda:0')
# observation: [[-0.61561076 -0.01567363 -0.03313352  0.03099767]]  action: [[-0.0509401]]  CTG= tensor([[-839.0106]], device='cuda:0')
# observation: [[-0.61715332 -0.01421646 -0.04400235  0.04198904]]  action: [[-0.03833974]]  CTG= tensor([[-839.2000]], device='cuda:0')
# observation: [[-0.61899541 -0.01261634 -0.04813553  0.03837883]]  action: [[-0.01782535]]  CTG= tensor([[-839.8038]], device='cuda:0')
# observation: [[-0.62087702 -0.01141864 -0.04599074  0.02196871]]  action: [[0.0016594]]  CTG= tensor([[-839.8312]], device='cuda:0')
# observation: [[-6.22611894e-01 -1.09802274e-02 -4.07927595e-02  3.37377650e-04]]  action: [[0.01155467]]  CTG= tensor([[-839.5509]], device='cuda:0')
# observation: [[-0.62416948 -0.01130709 -0.03710434 -0.01651358]]  action: [[0.00755222]]  CTG= tensor([[-839.2030]], device='cuda:0')
# observation: [[-0.62568743 -0.01204812 -0.03878307 -0.02063239]]  action: [[-0.00843077]]  CTG= tensor([[-838.7701]], device='cuda:0')
# observation: [[-0.6274082  -0.01264991 -0.04722523 -0.00973484]]  action: [[-0.02902207]]  CTG= tensor([[-838.3056]], device='cuda:0')
# observation: [[-0.62957641 -0.01258398 -0.06114907  0.01272351]]  action: [[-0.04601142]]  CTG= tensor([[-837.9673]], device='cuda:0')
# observation: [[-0.63230695 -0.0116282  -0.07535941  0.03493802]]  action: [[-0.04735311]]  CTG= tensor([[-838.1500]], device='cuda:0')
# observation: [[-0.6355275  -0.00996945 -0.08567731  0.04813853]]  action: [[-0.03579403]]  CTG= tensor([[-838.5699]], device='cuda:0')
# observation: [[-0.63900034 -0.00813615 -0.08800411  0.04394511]]  action: [[-0.01145719]]  CTG= tensor([[-838.9142]], device='cuda:0')
# observation: [[-0.64243807 -0.00672926 -0.08393439  0.02691414]]  action: [[0.00849099]]  CTG= tensor([[-839.0100]], device='cuda:0')
# observation: [[-0.64567027 -0.00606008 -0.07771816  0.00695537]]  action: [[0.01575292]]  CTG= tensor([[-838.8298]], device='cuda:0')
# observation: [[-0.6486762  -0.00610579 -0.07260106 -0.00902782]]  action: [[0.01304925]]  CTG= tensor([[-838.3424]], device='cuda:0')
# observation: [[-0.65158414 -0.00652948 -0.07279186 -0.01219846]]  action: [[-0.00265925]]  CTG= tensor([[-837.7909]], device='cuda:0')
# observation: [[-0.65462472 -0.00679582 -0.07921423 -0.00132652]]  action: [[-0.02153961]]  CTG= tensor([[-837.4844]], device='cuda:0')
# observation: [[-0.65800876 -0.00644287 -0.08996246  0.01875959]]  action: [[-0.0349098]]  CTG= tensor([[-837.5410]], device='cuda:0')
# observation: [[-0.66183095 -0.00528086 -0.10113641  0.03928077]]  action: [[-0.03650422]]  CTG= tensor([[-837.9217]], device='cuda:0')
# observation: [[-0.66599018 -0.00355104 -0.10684446  0.04743749]]  action: [[-0.02007483]]  CTG= tensor([[-838.3513]], device='cuda:0')
# observation: [[-0.67024997 -0.00176671 -0.10618674  0.04220584]]  action: [[-0.00048696]]  CTG= tensor([[-838.6415]], device='cuda:0')
# observation: [[-6.74393937e-01 -3.60892021e-04 -1.01059779e-01  2.85557750e-02]]  action: [[0.01368106]]  CTG= tensor([[-838.6927]], device='cuda:0')
# observation: [[-6.78309821e-01  4.84699583e-04 -9.47732423e-02  1.40953958e-02]]  action: [[0.01792372]]  CTG= tensor([[-838.5327]], device='cuda:0')
# observation: [[-0.68201137  0.00086718 -0.09032553  0.00523032]]  action: [[0.01296223]]  CTG= tensor([[-838.2787]], device='cuda:0')
# observation: [[-0.68560104  0.00106326 -0.08916355  0.00462223]]  action: [[0.00337363]]  CTG= tensor([[-838.0688]], device='cuda:0')
# observation: [[-0.68920162  0.00137168 -0.09086202  0.01077526]]  action: [[-0.00516175]]  CTG= tensor([[-837.9973]], device='cuda:0')
# observation: [[-0.69289261  0.00197769 -0.09368623  0.01952391]]  action: [[-0.00856697]]  CTG= tensor([[-838.0833]], device='cuda:0')
# observation: [[-0.69667829  0.00289379 -0.09560553  0.02636891]]  action: [[-0.0058028]]  CTG= tensor([[-838.2762]], device='cuda:0')
# observation: [[-0.70049489  0.00398765 -0.09524296  0.02851347]]  action: [[0.00125707]]  CTG= tensor([[-838.4928]], device='cuda:0')
# observation: [[-0.70424449  0.00506377 -0.09226365  0.0255507 ]]  action: [[0.00948519]]  CTG= tensor([[-838.6539]], device='cuda:0')
# observation: [[-0.70783592  0.00595371 -0.08733602  0.01921568]]  action: [[0.0158006]]  CTG= tensor([[-838.7180]], device='cuda:0')
# observation: [[-0.71122009  0.00658918 -0.08189639  0.01277833]]  action: [[0.01779676]]  CTG= tensor([[-838.7026]], device='cuda:0')
# observation: [[-0.71440137  0.00701895 -0.07718378  0.00885492]]  action: [[0.01597822]]  CTG= tensor([[-838.6595]], device='cuda:0')
# observation: [[-0.71741938  0.0073617  -0.0737255   0.0083619 ]]  action: [[0.01245261]]  CTG= tensor([[-838.6444]], device='cuda:0')
# observation: [[-0.72031878  0.00773701 -0.07125066  0.0104532 ]]  action: [[0.00964642]]  CTG= tensor([[-838.6925]], device='cuda:0')
# observation: [[-0.72312328  0.00821015 -0.06898091  0.01326299]]  action: [[0.00914634]]  CTG= tensor([[-838.8053]], device='cuda:0')
# observation: [[-0.72582458  0.00877283 -0.06609439  0.01496427]]  action: [[0.01114339]]  CTG= tensor([[-838.9658]], device='cuda:0')
# observation: [[-0.72838944  0.00936364 -0.06216252  0.01470231]]  action: [[0.01448692]]  CTG= tensor([[-839.1714]], device='cuda:0')
# observation: [[-0.73077737  0.00990955 -0.05725003  0.01273487]]  action: [[0.01768679]]  CTG= tensor([[-839.3896]], device='cuda:0')
# observation: [[-0.73295559  0.01035808 -0.05167664  0.00982747]]  action: [[0.01994491]]  CTG= tensor([[-839.6040]], device='cuda:0')
# observation: [[-0.73490703  0.01069241 -0.04590848  0.0070014 ]]  action: [[0.02078653]]  CTG= tensor([[-839.8092]], device='cuda:0')
# observation: [[-0.73663148  0.0109312  -0.04032478  0.00501993]]  action: [[0.02044678]]  CTG= tensor([[-840.0077]], device='cuda:0')
# observation: [[-0.73814659  0.01112933 -0.03543699  0.00493356]]  action: [[0.01851738]]  CTG= tensor([[-840.2259]], device='cuda:0')
# observation: [[-0.73947998  0.01135956 -0.03123721  0.00660657]]  action: [[0.01656056]]  CTG= tensor([[-840.4786]], device='cuda:0')
# observation: [[-0.74064502  0.0116584  -0.02702054  0.0083765 ]]  action: [[0.01670451]]  CTG= tensor([[-840.7617]], device='cuda:0')
# observation: [[-0.74162949  0.01200422 -0.02221159  0.00898172]]  action: [[0.018605]]  CTG= tensor([[-841.0732]], device='cuda:0')
# observation: [[-0.74240466  0.01234081 -0.01655829  0.00793644]]  action: [[0.02130598]]  CTG= tensor([[-841.4025]], device='cuda:0')
# observation: [[-0.74293482  0.01259911 -0.00996219  0.00507717]]  action: [[0.02433568]]  CTG= tensor([[-841.7234]], device='cuda:0')
# observation: [[-7.43184729e-01  1.27126339e-02 -2.54513332e-03  6.90400009e-04]]  action: [[0.02701014]]  CTG= tensor([[-842.0123]], device='cuda:0')
# observation: [[-0.74313585  0.0126522   0.0049806  -0.00365583]]  action: [[0.02752095]]  CTG= tensor([[-842.2715]], device='cuda:0')
# observation: [[-0.74279486  0.01244171  0.01206471 -0.00685816]]  action: [[0.02631425]]  CTG= tensor([[-842.5010]], device='cuda:0')
# observation: [[-0.74218429  0.01213429  0.01846403 -0.00854301]]  action: [[0.02430081]]  CTG= tensor([[-842.7101]], device='cuda:0')
# observation: [[-0.74133033  0.01178462  0.02423699 -0.00899639]]  action: [[0.02239943]]  CTG= tensor([[-842.9114]], device='cuda:0')
# observation: [[-0.74025317  0.01142875  0.02962502 -0.00886253]]  action: [[0.02118558]]  CTG= tensor([[-843.1155]], device='cuda:0')
# observation: [[-0.73896263  0.0110766   0.03490598 -0.00880911]]  action: [[0.02079398]]  CTG= tensor([[-843.3255]], device='cuda:0')
# observation: [[-0.73745914  0.0107162   0.04027174 -0.00926929]]  action: [[0.02098233]]  CTG= tensor([[-843.5402]], device='cuda:0')
# observation: [[-0.7357383   0.01032502  0.04577349 -0.01034588]]  action: [[0.02133131]]  CTG= tensor([[-843.7539]], device='cuda:0')
# observation: [[-0.7337961   0.00988178  0.05133977 -0.0118764 ]]  action: [[0.02146572]]  CTG= tensor([[-843.9592]], device='cuda:0')
# observation: [[-0.73163288  0.00937456  0.05682572 -0.01355614]]  action: [[0.02115369]]  CTG= tensor([[-844.1516]], device='cuda:0')
# observation: [[-0.72925481  0.00880319  0.06208398 -0.01509843]]  action: [[0.02037734]]  CTG= tensor([[-844.3283]], device='cuda:0')
# observation: [[-0.72666984  0.00816921  0.06717196 -0.01669853]]  action: [[0.01974791]]  CTG= tensor([[-844.4814]], device='cuda:0')
# observation: [[-0.72388615  0.0074724   0.07202115 -0.01825317]]  action: [[0.01888991]]  CTG= tensor([[-844.6123]], device='cuda:0')
# observation: [[-0.72091624  0.00672021  0.07648472 -0.01948418]]  action: [[0.0175649]]  CTG= tensor([[-844.7253]], device='cuda:0')
# observation: [[-0.71777746  0.00592866  0.08046671 -0.02023522]]  action: [[0.01592279]]  CTG= tensor([[-844.8234]], device='cuda:0')
# observation: [[-0.71448945  0.0051167   0.08394712 -0.02051634]]  action: [[0.01419456]]  CTG= tensor([[-844.9106]], device='cuda:0')
# observation: [[-0.7110713   0.00430002  0.08697435 -0.02047692]]  action: [[0.01259268]]  CTG= tensor([[-844.9902]], device='cuda:0')
# observation: [[-0.70753936  0.00348692  0.08963704 -0.02033819]]  action: [[0.01124681]]  CTG= tensor([[-845.0634]], device='cuda:0')
# observation: [[-0.70387862  0.002613    0.09341081 -0.02348456]]  action: [[0.01434536]]  CTG= tensor([[-845.0562]], device='cuda:0')
# observation: [[-0.70002699  0.00150825  0.09917774 -0.03185284]]  action: [[0.02014637]]  CTG= tensor([[-844.9129]], device='cuda:0')
# observation: [[-6.95922008e-01  4.58625028e-06  1.06081577e-01 -4.34641991e-02]]  action: [[0.02339184]]  CTG= tensor([[-844.6558]], device='cuda:0')
# observation: [[-0.6915947  -0.00185501  0.11030892 -0.04979515]]  action: [[0.01506985]]  CTG= tensor([[-844.3486]], device='cuda:0')
# observation: [[-0.6871959  -0.0037699   0.10967301 -0.04637763]]  action: [[-7.6582655e-05]]  CTG= tensor([[-844.0323]], device='cuda:0')
# observation: [[-0.68292877 -0.00534079  0.10373516 -0.03267236]]  action: [[-0.01676975]]  CTG= tensor([[-843.8137]], device='cuda:0')
# observation: [[-0.67897997 -0.00621879  0.09375521 -0.01169843]]  action: [[-0.02976713]]  CTG= tensor([[-843.8002]], device='cuda:0')
# observation: [[-0.67544046 -0.00627107  0.08325388  0.00878424]]  action: [[-0.03207352]]  CTG= tensor([[-844.0026]], device='cuda:0')
# observation: [[-0.6721827  -0.00584461  0.07963295  0.01256825]]  action: [[-0.01178383]]  CTG= tensor([[-844.1851]], device='cuda:0')
# observation: [[-6.68920545e-01 -5.60744861e-03  8.34508776e-02 -4.82222154e-04]]  action: [[0.01068891]]  CTG= tensor([[-844.3244]], device='cuda:0')
# observation: [[-0.66543167 -0.00604609  0.09096987 -0.02124747]]  action: [[0.02217472]]  CTG= tensor([[-844.3311]], device='cuda:0')
# observation: [[-0.66164117 -0.00730487  0.09854884 -0.04165707]]  action: [[0.02261639]]  CTG= tensor([[-844.0913]], device='cuda:0')
# observation: [[-0.65756913 -0.00933279  0.10506452 -0.0598885 ]]  action: [[0.0193891]]  CTG= tensor([[-843.5040]], device='cuda:0')
# observation: [[-0.65332631 -0.01190128  0.10711332 -0.06892303]]  action: [[0.0055951]]  CTG= tensor([[-842.7211]], device='cuda:0')
# observation: [[-0.64917128 -0.01447677  0.10070254 -0.06048637]]  action: [[-0.02061187]]  CTG= tensor([[-841.6146]], device='cuda:0')
# observation: [[-0.64550254 -0.01623892  0.08282064 -0.0284283 ]]  action: [[-0.05626722]]  CTG= tensor([[-840.9982]], device='cuda:0')
# observation: [[-0.64280628 -0.01618827  0.05208555  0.03014119]]  action: [[-0.09630903]]  CTG= tensor([[-840.7651]], device='cuda:0')
# observation: [[-0.64127919 -0.01399065  0.02430621  0.07947663]]  action: [[-0.08862913]]  CTG= tensor([[-841.4110]], device='cuda:0')
# observation: [[-0.64042419 -0.01084243  0.01838516  0.07856608]]  action: [[-0.02305804]]  CTG= tensor([[-842.6641]], device='cuda:0')
# observation: [[-0.63946762 -0.00845426  0.02934273  0.04182749]]  action: [[0.02884655]]  CTG= tensor([[-843.6593]], device='cuda:0')
# observation: [[-0.63790104 -0.00785278  0.04889467 -0.01089764]]  action: [[0.05626426]]  CTG= tensor([[-843.8549]], device='cuda:0')
# observation: [[-0.63549733 -0.00942466  0.0712349  -0.06722043]]  action: [[0.06591774]]  CTG= tensor([[-843.3019]], device='cuda:0')
# observation: [[-0.63224538 -0.0131177   0.09135715 -0.11746291]]  action: [[0.05983038]]  CTG= tensor([[-842.1829]], device='cuda:0')
# observation: [[-0.62930925 -0.01624953  0.05563052 -0.04083323]]  action: [[-0.10878067]]  CTG= tensor([[-840.9021]], device='cuda:0')
# observation: [[-0.62746973 -0.01721621  0.03641728 -0.00815883]]  action: [[-0.06164888]]  CTG= tensor([[-840.6375]], device='cuda:0')
# observation: [[-0.62653426 -0.01661265  0.01041931  0.03780366]]  action: [[-0.08314889]]  CTG= tensor([[-840.1923]], device='cuda:0')
# observation: [[-0.62648539 -0.01455896 -0.00796995  0.0649009 ]]  action: [[-0.06100396]]  CTG= tensor([[-840.4092]], device='cuda:0')
# observation: [[-0.62686212 -0.01212671 -0.01092185  0.0572946 ]]  action: [[-0.01438795]]  CTG= tensor([[-841.2640]], device='cuda:0')
# observation: [[-0.62712503 -0.01048273 -0.00230145  0.025669  ]]  action: [[0.02141505]]  CTG= tensor([[-841.9539]], device='cuda:0')
# observation: [[-0.626975   -0.01020019  0.00974275 -0.01097574]]  action: [[0.03288803]]  CTG= tensor([[-842.0183]], device='cuda:0')
# observation: [[-0.62638126 -0.01125433  0.01991877 -0.04151608]]  action: [[0.02806186]]  CTG= tensor([[-841.5970]], device='cuda:0')
# observation: [[-0.62554477 -0.01313967  0.021926   -0.05296954]]  action: [[0.00367195]]  CTG= tensor([[-840.9099]], device='cuda:0')
# observation: [[-0.62488573 -0.01491078  0.01108831 -0.03617959]]  action: [[-0.03548618]]  CTG= tensor([[-840.2993]], device='cuda:0')
# observation: [[-0.62481253 -0.01570714 -0.00736049 -0.00425144]]  action: [[-0.05941074]]  CTG= tensor([[-839.6947]], device='cuda:0')
# observation: [[-0.62550473 -0.01520882 -0.02720503  0.02879508]]  action: [[-0.06458647]]  CTG= tensor([[-838.9475]], device='cuda:0')
# observation: [[-0.62691663 -0.01358325 -0.04338138  0.05246757]]  action: [[-0.05408839]]  CTG= tensor([[-838.9174]], device='cuda:0')
# observation: [[-0.62876838 -0.01148315 -0.0492428   0.05294157]]  action: [[-0.02298323]]  CTG= tensor([[-839.7893]], device='cuda:0')
# observation: [[-0.63065954 -0.00977698 -0.04537634  0.03298086]]  action: [[0.00698806]]  CTG= tensor([[-840.1350]], device='cuda:0')
# observation: [[-0.63230803 -0.00902191 -0.03710398  0.00530651]]  action: [[0.02120763]]  CTG= tensor([[-839.9843]], device='cuda:0')
# observation: [[-0.63363339 -0.00931499 -0.02919524 -0.01967163]]  action: [[0.02089501]]  CTG= tensor([[-839.7159]], device='cuda:0')
# observation: [[-0.63475541 -0.01032689 -0.02690222 -0.03096958]]  action: [[0.00434727]]  CTG= tensor([[-839.2546]], device='cuda:0')
# observation: [[-0.63595168 -0.01141459 -0.03287752 -0.02373721]]  action: [[-0.02071707]]  CTG= tensor([[-838.7017]], device='cuda:0')
# observation: [[-0.63753266 -0.01190331 -0.04612516 -0.00111886]]  action: [[-0.04318558]]  CTG= tensor([[-838.2876]], device='cuda:0')
# observation: [[-0.63970923 -0.01136674 -0.0626668   0.02764519]]  action: [[-0.05377785]]  CTG= tensor([[-838.1018]], device='cuda:0')
# observation: [[-0.64249624 -0.00981649 -0.07667686  0.04985818]]  action: [[-0.04659196]]  CTG= tensor([[-838.5850]], device='cuda:0')
# observation: [[-0.6456632  -0.00778827 -0.08170496  0.05192254]]  action: [[-0.01948653]]  CTG= tensor([[-839.0983]], device='cuda:0')
# observation: [[-0.64887159 -0.00601159 -0.07876945  0.03746407]]  action: [[0.00512422]]  CTG= tensor([[-839.3927]], device='cuda:0')
# ...
# observation: [[-0.69889117  0.00326574 -0.05605133  0.01038375]]  action: [[0.00473917]]  CTG= tensor([[-839.2337]], device='cuda:0')
# observation: [[-0.70110341  0.00369143 -0.05456919  0.01097933]]  action: [[0.00541092]]  CTG= tensor([[-839.3145]], device='cuda:0')
# observation: [[-0.70324844  0.00412976 -0.05269183  0.01102631]]  action: [[0.00675173]]  CTG= tensor([[-839.4094]], device='cuda:0')
# observation: [[-0.7053089   0.00455596 -0.0503412   0.0103805 ]]  action: [[0.00834496]]  CTG= tensor([[-839.5140]], device='cuda:0')
# observation: [[-0.7072673   0.00494616 -0.04758961  0.00922644]]  action: [[0.00973196]]  CTG= tensor([[-839.6231]], device='cuda:0')
# observation: [[-0.7091113   0.00528839 -0.04462043  0.00797391]]  action: [[0.01056612]]  CTG= tensor([[-839.7337]], device='cuda:0')
# observation: [[-0.71083636  0.00558755 -0.04164128  0.00706001]]  action: [[0.01076193]]  CTG= tensor([[-839.8481]], device='cuda:0')
# observation: [[-0.71244305  0.00585831 -0.03870061  0.00654258]]  action: [[0.01079173]]  CTG= tensor([[-839.9667]], device='cuda:0')
# observation: [[-0.71393198  0.0061135  -0.03575305  0.00627509]]  action: [[0.01094193]]  CTG= tensor([[-840.0925]], device='cuda:0')
# observation: [[-0.71530102  0.00635825 -0.03270538  0.0060191 ]]  action: [[0.01136393]]  CTG= tensor([[-840.2267]], device='cuda:0')
# observation: [[-0.71654442  0.00658886 -0.02947148  0.00556731]]  action: [[0.01204283]]  CTG= tensor([[-840.3680]], device='cuda:0')
# observation: [[-0.717654    0.00679571 -0.02601465  0.00483118]]  action: [[0.01283259]]  CTG= tensor([[-840.5148]], device='cuda:0')
# observation: [[-0.71862139  0.00696853 -0.02236128  0.003862  ]]  action: [[0.01354159]]  CTG= tensor([[-840.6641]], device='cuda:0')
# observation: [[-0.71944009  0.00710079 -0.01858011  0.00279675]]  action: [[0.0140375]]  CTG= tensor([[-840.8143]], device='cuda:0')
# observation: [[-0.7201066   0.00719168 -0.01475027  0.00178446]]  action: [[0.01428396]]  CTG= tensor([[-840.9637]], device='cuda:0')
# observation: [[-0.72062008  0.00724513 -0.01092838  0.00091545]]  action: [[0.01434536]]  CTG= tensor([[-841.1134]], device='cuda:0')
# observation: [[-7.20981267e-01  7.26697020e-03 -7.13425970e-03  1.95363412e-04]]  action: [[0.01433194]]  CTG= tensor([[-841.2642]], device='cuda:0')
# observation: [[-7.21191003e-01  7.26183993e-03 -3.35536294e-03 -4.39390124e-04]]  action: [[0.01434297]]  CTG= tensor([[-841.4158]], device='cuda:0')
# observation: [[-7.21249344e-01  7.23129909e-03  4.35966887e-04 -1.08012932e-03]]  action: [[0.01442672]]  CTG= tensor([[-841.5691]], device='cuda:0')
# observation: [[-0.7211554   0.00717376  0.00425902 -0.00179369]]  action: [[0.01456023]]  CTG= tensor([[-841.7225]], device='cuda:0')
# observation: [[-0.72090793  0.00708592  0.00811327 -0.00260005]]  action: [[0.01468451]]  CTG= tensor([[-841.8755]], device='cuda:0')
# observation: [[-0.72050612  0.00696465  0.01197602 -0.00347047]]  action: [[0.01473189]]  CTG= tensor([[-842.0262]], device='cuda:0')
# observation: [[-0.71995038  0.00680855  0.01581082 -0.00434868]]  action: [[0.01465917]]  CTG= tensor([[-842.1743]], device='cuda:0')
# observation: [[-0.71924257  0.00661841  0.0195804  -0.00518028]]  action: [[0.01446218]]  CTG= tensor([[-842.3181]], device='cuda:0')
# observation: [[-0.71838586  0.00639674  0.02325623 -0.00593247]]  action: [[0.01416624]]  CTG= tensor([[-842.4584]], device='cuda:0')
# observation: [[-0.71738437  0.00614689  0.02682045 -0.00659605]]  action: [[0.01380355]]  CTG= tensor([[-842.5952]], device='cuda:0')
# observation: [[-0.71624223  0.00587108  0.03028872 -0.00723608]]  action: [[0.01347602]]  CTG= tensor([[-842.7274]], device='cuda:0')
# observation: [[-0.71496346  0.00557013  0.03365315 -0.00785881]]  action: [[0.01311452]]  CTG= tensor([[-842.8557]], device='cuda:0')
# observation: [[-0.71355224  0.00524436  0.03691125 -0.00848193]]  action: [[0.01273573]]  CTG= tensor([[-842.9791]], device='cuda:0')
# observation: [[-0.71201304  0.00489376  0.04005322 -0.00910525]]  action: [[0.0123179]]  CTG= tensor([[-843.0964]], device='cuda:0')
# observation: [[-0.7103508   0.0045186   0.04306344 -0.0097153 ]]  action: [[0.01184345]]  CTG= tensor([[-843.2081]], device='cuda:0')
# observation: [[-0.70857117  0.0041198   0.04592354 -0.01029261]]  action: [[0.01130373]]  CTG= tensor([[-843.3127]], device='cuda:0')
# observation: [[-0.7066805   0.00369901  0.04861607 -0.01081987]]  action: [[0.01070143]]  CTG= tensor([[-843.4095]], device='cuda:0')
# observation: [[-0.70468573  0.00325837  0.05112872 -0.01129073]]  action: [[0.01005203]]  CTG= tensor([[-843.4998]], device='cuda:0')
# observation: [[-0.70259424  0.0028001   0.05345265 -0.01170524]]  action: [[0.00936658]]  CTG= tensor([[-843.5822]], device='cuda:0')
# observation: [[-0.70041365  0.00232625  0.05558443 -0.01207379]]  action: [[0.00866205]]  CTG= tensor([[-843.6567]], device='cuda:0')
# observation: [[-0.69815172  0.0018385   0.05752028 -0.01240367]]  action: [[0.00793815]]  CTG= tensor([[-843.7234]], device='cuda:0')
# observation: [[-0.69581635  0.00133828  0.05925658 -0.01270077]]  action: [[0.00719608]]  CTG= tensor([[-843.7816]], device='cuda:0')
# observation: [[-0.69341565  0.00082692  0.06078716 -0.01296355]]  action: [[0.00642867]]  CTG= tensor([[-843.8313]], device='cuda:0')
# observation: [[-6.90957987e-01  3.05891239e-04  6.21048595e-02 -1.31870678e-02]]  action: [[0.00563324]]  CTG= tensor([[-843.8721]], device='cuda:0')
# observation: [[-6.88452054e-01 -2.23064043e-04  6.32011886e-02 -1.33622532e-02]]  action: [[0.00480623]]  CTG= tensor([[-843.9037]], device='cuda:0')
# observation: [[-0.68590684 -0.00075789  0.06406933 -0.01348267]]  action: [[0.00395299]]  CTG= tensor([[-843.9315]], device='cuda:0')
# observation: [[-0.68333152 -0.00129642  0.06470645 -0.01354943]]  action: [[0.00308604]]  CTG= tensor([[-843.9648]], device='cuda:0')
# observation: [[-0.68072126 -0.00186917  0.06581493 -0.01517866]]  action: [[0.00433207]]  CTG= tensor([[-843.9517]], device='cuda:0')
# observation: [[-0.67806052 -0.00253004  0.06723034 -0.01795731]]  action: [[0.00510068]]  CTG= tensor([[-843.8990]], device='cuda:0')
# observation: [[-0.67534998 -0.00329556  0.06830749 -0.02043621]]  action: [[0.00391603]]  CTG= tensor([[-843.8098]], device='cuda:0')
# observation: [[-0.67261481 -0.00412905  0.06846584 -0.02139116]]  action: [[0.00093759]]  CTG= tensor([[-843.6904]], device='cuda:0')
# observation: [[-0.6699009  -0.00495118  0.06724849 -0.01990088]]  action: [[-0.00347494]]  CTG= tensor([[-843.5663]], device='cuda:0')
# observation: [[-0.66726591 -0.00566023  0.06452151 -0.01575263]]  action: [[-0.00834047]]  CTG= tensor([[-843.4688]], device='cuda:0')
# observation: [[-0.66475488 -0.00618594  0.06104877 -0.01070974]]  action: [[-0.01092284]]  CTG= tensor([[-843.4022]], device='cuda:0')
# observation: [[-0.66237963 -0.00653165  0.05772758 -0.00670299]]  action: [[-0.01075982]]  CTG= tensor([[-843.3691]], device='cuda:0')
# observation: [[-0.66011877 -0.00676992  0.05532298 -0.00528019]]  action: [[-0.00821142]]  CTG= tensor([[-843.3508]], device='cuda:0')
# observation: [[-0.65793021 -0.00701218  0.05410856 -0.00686154]]  action: [[-0.00475108]]  CTG= tensor([[-843.3184]], device='cuda:0')
# observation: [[-0.65577377 -0.00735854  0.05371572 -0.01047704]]  action: [[-0.00234305]]  CTG= tensor([[-843.2476]], device='cuda:0')
# observation: [[-0.6536328  -0.00785279  0.05333766 -0.01428349]]  action: [[-0.00236153]]  CTG= tensor([[-843.1263]], device='cuda:0')
# observation: [[-0.65151859 -0.00847763  0.05238176 -0.01704697]]  action: [[-0.00421344]]  CTG= tensor([[-842.9460]], device='cuda:0')
# observation: [[-0.64947314 -0.00915111  0.04990531 -0.01676813]]  action: [[-0.00897407]]  CTG= tensor([[-842.7464]], device='cuda:0')
# observation: [[-0.6475682  -0.0097302   0.04536129 -0.01236661]]  action: [[-0.01546441]]  CTG= tensor([[-842.5712]], device='cuda:0')
# observation: [[-0.64588233 -0.01006186  0.03895245 -0.0043986 ]]  action: [[-0.02139864]]  CTG= tensor([[-842.4640]], device='cuda:0')
# observation: [[-0.64446906 -0.01005116  0.03172716  0.0048023 ]]  action: [[-0.0241646]]  CTG= tensor([[-842.4464]], device='cuda:0')
# observation: [[-0.64330956 -0.00976267  0.02625164  0.00960758]]  action: [[-0.01910625]]  CTG= tensor([[-842.4569]], device='cuda:0')
# observation: [[-0.64230172 -0.00943705  0.02413146  0.00677376]]  action: [[-0.00902533]]  CTG= tensor([[-842.4413]], device='cuda:0')
# observation: [[-0.64133391 -0.00931953  0.02424706 -0.00077222]]  action: [[-0.00215053]]  CTG= tensor([[-842.3861]], device='cuda:0')
# observation: [[-0.64034298 -0.00953697  0.02529047 -0.01001712]]  action: [[0.00080884]]  CTG= tensor([[-842.2253]], device='cuda:0')
# observation: [[-0.63933145 -0.01007025  0.02528766 -0.01666361]]  action: [[-0.0022596]]  CTG= tensor([[-841.9719]], device='cuda:0')
# observation: [[-0.6383738  -0.01074834  0.0226088  -0.01737005]]  action: [[-0.0104007]]  CTG= tensor([[-841.6702]], device='cuda:0')
# observation: [[-0.63758527 -0.01132317  0.01683981 -0.01157135]]  action: [[-0.01996158]]  CTG= tensor([[-841.3799]], device='cuda:0')
# observation: [[-0.63707113 -0.01158137  0.00888934 -0.00153611]]  action: [[-0.02688375]]  CTG= tensor([[-841.1556]], device='cuda:0')
# observation: [[-6.36882613e-01 -1.14351987e-02  5.52030167e-04  8.72468463e-03]]  action: [[-0.02837834]]  CTG= tensor([[-841.0225]], device='cuda:0')
# observation: [[-0.63699704 -0.01095659 -0.00627036  0.01520497]]  action: [[-0.02401022]]  CTG= tensor([[-840.9661]], device='cuda:0')
# observation: [[-0.63732985 -0.01034236 -0.01037935  0.01561758]]  action: [[-0.01584052]]  CTG= tensor([[-840.9405]], device='cuda:0')
# observation: [[-0.63777238 -0.00982712 -0.01176312  0.01031679]]  action: [[-0.00746458]]  CTG= tensor([[-840.8873]], device='cuda:0')
# observation: [[-0.63823867 -0.0095823  -0.01156725  0.00208436]]  action: [[-0.0024566]]  CTG= tensor([[-840.7630]], device='cuda:0')
# observation: [[-0.63870123 -0.00964478 -0.01156862 -0.00512359]]  action: [[-0.00283389]]  CTG= tensor([[-840.5555]], device='cuda:0')
# observation: [[-0.63920051 -0.00990489 -0.01339333 -0.00789901]]  action: [[-0.00823586]]  CTG= tensor([[-840.2914]], device='cuda:0')
# observation: [[-0.63982503 -0.01015735 -0.01782105 -0.00482155]]  action: [[-0.0161448]]  CTG= tensor([[-840.0199]], device='cuda:0')
# observation: [[-0.64067112 -0.01019163 -0.02446865  0.00298696]]  action: [[-0.02301631]]  CTG= tensor([[-839.7960]], device='cuda:0')
# observation: [[-0.64180025 -0.00988227 -0.03197754  0.01240561]]  action: [[-0.02581654]]  CTG= tensor([[-839.6541]], device='cuda:0')
# observation: [[-0.64321203 -0.00924074 -0.0386106   0.01969182]]  action: [[-0.02329795]]  CTG= tensor([[-839.5948]], device='cuda:0')
# observation: [[-0.64484397 -0.00840761 -0.04299694  0.02209243]]  action: [[-0.0164911]]  CTG= tensor([[-839.5857]], device='cuda:0')
# observation: [[-0.64659209 -0.00760263 -0.0444287   0.01836563]]  action: [[-0.00738441]]  CTG= tensor([[-839.5790]], device='cuda:0')
# observation: [[-0.64836328 -0.00700743 -0.04415157  0.01160419]]  action: [[-0.00191449]]  CTG= tensor([[-839.5381]], device='cuda:0')
# observation: [[-0.6501163  -0.00668164 -0.04351455  0.00484217]]  action: [[-0.00051646]]  CTG= tensor([[-839.4238]], device='cuda:0')
# observation: [[-0.65186416 -0.0065668  -0.04388585  0.0009743 ]]  action: [[-0.0033307]]  CTG= tensor([[-839.2537]], device='cuda:0')
# observation: [[-0.65366564 -0.00651127 -0.04618656  0.00179902]]  action: [[-0.00904976]]  CTG= tensor([[-839.0742]], device='cuda:0')
# observation: [[-0.65559769 -0.00633352 -0.0504103   0.00704773]]  action: [[-0.01486449]]  CTG= tensor([[-838.9348]], device='cuda:0')
# observation: [[-0.65771886 -0.00590119 -0.05564378  0.01454719]]  action: [[-0.01797496]]  CTG= tensor([[-838.8702]], device='cuda:0')
# observation: [[-0.66003464 -0.00520242 -0.06014887  0.02044491]]  action: [[-0.01580565]]  CTG= tensor([[-838.9752]], device='cuda:0')
# observation: [[-0.66248732 -0.00436094 -0.06249799  0.02177583]]  action: [[-0.0092095]]  CTG= tensor([[-839.0873]], device='cuda:0')
# observation: [[-0.66499173 -0.0035498  -0.06274186  0.01897985]]  action: [[-0.00262289]]  CTG= tensor([[-839.1389]], device='cuda:0')
# observation: [[-0.667481   -0.00289056 -0.06174123  0.01417972]]  action: [[0.00144602]]  CTG= tensor([[-839.1117]], device='cuda:0')
# observation: [[-0.66992815 -0.00241149 -0.06063154  0.00992789]]  action: [[0.00208528]]  CTG= tensor([[-839.0266]], device='cuda:0')
# observation: [[-0.67234599 -0.00205478 -0.06027033  0.00800507]]  action: [[7.064082e-05]]  CTG= tensor([[-838.9288]], device='cuda:0')
# observation: [[-0.67476968 -0.00171974 -0.06091948  0.00880207]]  action: [[-0.00281989]]  CTG= tensor([[-838.8617]], device='cuda:0')
# observation: [[-0.67723301 -0.00131597 -0.06225047  0.01142982]]  action: [[-0.00478118]]  CTG= tensor([[-838.8491]], device='cuda:0')
# observation: [[-0.67974995 -0.00080149 -0.06360194  0.0143555 ]]  action: [[-0.00476181]]  CTG= tensor([[-838.8887]], device='cuda:0')
# observation: [[-6.82308552e-01 -1.92169452e-04 -6.43370616e-02  1.62057556e-02]]  action: [[-0.00279008]]  CTG= tensor([[-838.9573]], device='cuda:0')
# observation: [[-6.84877300e-01  4.55899453e-04 -6.41128342e-02  1.63254493e-02]]  action: [[0.00027121]]  CTG= tensor([[-839.0266]], device='cuda:0')
# observation: [[-0.68741872  0.00107798 -0.06297253  0.01492264]]  action: [[0.00325263]]  CTG= tensor([[-839.0762]], device='cuda:0')
# observation: [[-0.68990289  0.00162972 -0.06125042  0.01280553]]  action: [[0.00525118]]  CTG= tensor([[-839.0992]], device='cuda:0')
# observation: [[-0.69231504  0.00210164 -0.05936995  0.01091225]]  action: [[0.00596673]]  CTG= tensor([[-839.1050]], device='cuda:0')
# observation: [[-0.69465511  0.00251547 -0.05764355  0.0098778 ]]  action: [[0.00571133]]  CTG= tensor([[-839.1595]], device='cuda:0')
# observation: [[-0.69693097  0.00290765 -0.05615798  0.0098121 ]]  action: [[0.00515939]]  CTG= tensor([[-839.2188]], device='cuda:0')
# observation: [[-0.69914928  0.00330871 -0.05476564  0.01031583]]  action: [[0.00502707]]  CTG= tensor([[-839.2897]], device='cuda:0')
# observation: [[-0.70130769  0.00372697 -0.05316354  0.01067795]]  action: [[0.00580103]]  CTG= tensor([[-839.3718]], device='cuda:0')
# observation: [[-0.70339452  0.00414963 -0.05118741  0.01054331]]  action: [[0.00708044]]  CTG= tensor([[-839.4669]], device='cuda:0')
# observation: [[-0.70539397  0.00455542 -0.04879488  0.00983996]]  action: [[0.00850082]]  CTG= tensor([[-839.5701]], device='cuda:0')
# observation: [[-0.7072909   0.0049254  -0.04606182  0.00875101]]  action: [[0.00970007]]  CTG= tensor([[-839.6771]], device='cuda:0')
# observation: [[-0.70907547  0.00525258 -0.04317601  0.00769129]]  action: [[0.01033069]]  CTG= tensor([[-839.7874]], device='cuda:0')
# observation: [[-0.71074424  0.0055435  -0.04027071  0.00692658]]  action: [[0.01054616]]  CTG= tensor([[-839.9020]], device='cuda:0')
# observation: [[-0.71229682  0.00580991 -0.03736564  0.00645685]]  action: [[0.01068533]]  CTG= tensor([[-840.0215]], device='cuda:0')
# observation: [[-0.71373224  0.00606062 -0.03441259  0.00613688]]  action: [[0.01095683]]  CTG= tensor([[-840.1483]], device='cuda:0')
# observation: [[-0.71504708  0.00629768 -0.03133579  0.00577244]]  action: [[0.01144946]]  CTG= tensor([[-840.2820]], device='cuda:0')
# observation: [[-0.71623519  0.00651641 -0.02807692  0.00521944]]  action: [[0.01211525]]  CTG= tensor([[-840.4224]], device='cuda:0')
# observation: [[-0.71728904  0.00670849 -0.0246221   0.00443759]]  action: [[0.01282156]]  CTG= tensor([[-840.5669]], device='cuda:0')
# observation: [[-0.71820147  0.00686609 -0.02100558  0.00349127]]  action: [[0.01342119]]  CTG= tensor([[-840.7137]], device='cuda:0')
# observation: [[-0.71896724  0.00698501 -0.01728858  0.00249681]]  action: [[0.01382888]]  CTG= tensor([[-840.8610]], device='cuda:0')
# observation: [[-7.43772735e-03  3.14060037e+00 -2.58403952e-03  8.53529978e-03]]  action: [[0.01403541]]  CTG= tensor([[-841.0085]], device='cuda:0')
